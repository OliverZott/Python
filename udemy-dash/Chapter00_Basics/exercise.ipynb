# %% [markdown]
# #######
# # AUFGABE 1: Importiere Pandas und NumPy
# ######
#
#
#
# #######
# # AUFGABE 2: Setze NumPy's Zufallszahlengenerator auf den Seed 101
# ######
#
#
# #######
# # AUFGABE 3: Erzeuge eine NumPy-Matrix mit 100 Zeilen und 5 Spalten bestehend
# #                     aus zuf�lligen Integers zwischen 1 und 100. (Beachte hierbei,
# #                     dass die obere Grenze exklusive sein kann).
# ######
#
#
# #######
# # AUFGABE 4: Verwende jetzt pd.DataFrame() um diesen NumPy-Array als DataFrame einzulesen.
# #                     �bergib dazu einfach das NumPy-Array in die Funktion pd.DataFrame, um ein
# #                     DataFrame zu erhalten. Pandas kennzeichnet die Spalten automatisch mit 0-4
# ######
#
#
# #######
# # AUFGABE 5: Verwende mit dem von dir gerade erzeugten Dataframe [df.columns = [...]]
# #                    (https://stackoverflow.com/questions/11346283/renaming-columns-in-pandas)
# #                    um die Spalten in Pandas umzubennen in ['f1','f2','f3','f4','label'].
# ######
#
#
# #######
# # AUFGABE 6: Bisher waren die Aufgaben hoffentlich einfach zu l�sen..
# #         In dieser letzten Aufgabe wird dir erlauben, schnell zu sehen, ob du in
# #         Pandas auf dem richtigen Level stehst! Mache das folgende:
# #         Erzeuge ein DataFrame mit den Spalten ['A','B','C','D'], bei dem jede Spalte
# #         50 Zeilen mit Zufallszahlen besitzt. Die Zufallszahlen sollen
# #         zwischen 0 und 100 liegen. (Hinweis: Verwende NumPy, um die Zahlen zu erzeugen
# #         und �bergebe sie dann pd.DataFrame(), beachte hierbei die Parameter
# #         f�r diesen Aufruf.)
# ######

# %%
# AUFGABE 1: Importiere Pandas und NumPy

import pandas as pd
import numpy as np

# %%
# AUFGABE 2: Setze NumPy's Zufallszahlengenerator auf den Seed 101

np.random.seed(42)


# AUFGABE 3: Erzeuge eine NumPy-Matrix mit 100 Zeilen und 5 Spalten bestehend
#                     aus zuf�lligen Integers zwischen 1 und 100. (Beachte hierbei,
#                     dass die obere Grenze exklusive sein kann).

rand = np.random.randint(1, 101, (100, 5))

# %%
# AUFGABE 4: Verwende jetzt pd.DataFrame() um diesen NumPy-Array als DataFrame einzulesen.
#                     uebergib dazu einfach das NumPy-Array in die Funktion pd.DataFrame, um ein
#                     DataFrame zu erhalten. Pandas kennzeichnet die Spalten automatisch mit 0-4

df = pd.DataFrame(rand)


# AUFGABE 5: Verwende mit dem von dir gerade erzeugten Dataframe [df.columns = [...]]
#                    (https://stackoverflow.com/questions/11346283/renaming-columns-in-pandas)
#                    um die Spalten in Pandas umzubennen in ['f1','f2','f3','f4','label'].

df.columns = "f1 f2 f3 f4 label".split(" ")

print(df)
# Out:
#     f1   f2  f3  f4  label
# 0   52   93  15  72     61
# 1   21   83  87  75     75
# 2   88  100  24   3     22
# 3   53    2  88  30     38
# 4    2   64  60  21     33
# ..  ..  ...  ..  ..    ...
# 95  92   58  55  90     90
# 96  62   23   9  12      1
# 97  58    1  34  96     48
# 98  89    1  16  61     64
# 99  63   69  22  93     67
#
# [100 rows x 5 columns]

# %%
# AUFGABE 6:
#         Erzeuge ein DataFrame mit den Spalten ['A','B','C','D'], bei dem jede Spalte
#         50 Zeilen mit Zufallszahlen besitzt. Die Zufallszahlen sollen
#         zwischen 0 und 100 liegen.

rand_values = np.random.randint(0, 101, 200)
rand_mat = rand_values.reshape(50, 4)

# rand_values = np.random.randint(0, 101, (50, 4))


col_names = ['A', 'B', 'C', 'D']
df = pd.DataFrame(rand_mat, columns=col_names)

print(df)
# Out:
#      A   B    C    D
# 0   91  61   45   63
# 1    1  53   64   50
# 2   52  35   25   28
# 3   20  10   39   10
# 4   35  58   38   98
# 5   53  97   54   23
# 6   21  68   55   32
# 7   35  19   82   98
# 8   80  61   97   72
# 9   25  65   72   72
# 10  39  16    0   88
# 11  60  42   41   24
# 12  38  34    2  100
# 13  43  50   93   97
# 14  11  18  100   43
# 15  58  48   60   16
# 16  73  56   54   46
# 17  11  61   79   87
# 18  82   7   94   20
# 19  80  86  100   79
# 20  69  71   24   81
# 21  88  11   14   58
# 22  25  25   46   31
# 23   9  15   70   16
# 24  22  25   84   85
# 25   6  13   78    6
# 26   8  47   71   58
# 27  86  92   81   94
# 28  93  38   98   17
# 29  58  16   13   30
# 30  23  98   59   44
# 31  97   2   36   42
# 32  39  89   54   86
# 33  38  14    3   92
# 34  85  24   12   81
# 35  32  15   41   65
# 36  54  98   41   33
# 37  29  12   12   17
# 38  31  95   98   38
# 39  45  28   61   92
# 40  61  56   15   55
# 41   9  29   24   83
# 42   4  64   93   48
# 43   2  44   13   29
# 44  67  17   61   36
# 45  24  47   64   52
# 46  78  72   14   48
# 47  87  67   11   58
# 48  36  60  100   42
# 49  69  38   55   62
